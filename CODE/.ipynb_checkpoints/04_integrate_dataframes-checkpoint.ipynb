# %% [markdown]
# Zach Tretter
#
# June 2020

# %% [markdown]
# # Step 4 - Build Overall Dataframe
#
# ### Read in Individual Dataframes
# * [Fill Times](#Read-in-Fill-Times)
# * [Weather](#Read-in-Weather-Data)
# * [Visits](#Read-in-Visits-Data)
# * [Air Quality](#Read-in-Air-Quality-Data)
# * [Campground Attributes](#Read-in-Campground-Attributes)
#
# ### Integrate Dataframes
#
# * Fill Times as foundation of [Final Dataframe](#Instantiate-final-df-as-df_fill)
# * Left Join Dataframe with Air Quality on Date (AQI is same for all campsites)
# * Left Join Dataframe with Monthly Visits on 'key_year_month') (e.g. YYYY_MMM)
# * Left Join Dataframe with Campground Attributes on 'cg_name' (Campground Name)
#     * Can now create 'supply' variable
#     * Can now create 'date_wxstation'
# * Left Join Dataframe with Weather on 'date_wxstation'
# * Drop columns no longer needed
#
# ### Export to CSV
# * [Export](#Export-Dataframe)

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# -------------
#
# ## Read in Fill Times

# %%
# Read in the data
df_fill = pd.read_csv('../data/02_filltimes_clean.csv')

df_fill.drop(columns='Unnamed: 0',inplace=True)

# Convert date to a datetype
df_fill['date'] = pd.to_datetime(df_fill['date'])

df_fill = df_fill.set_index('key_name_date');

# %% [markdown]
# #### View Dataframe

# %%
df_fill.T
# Out:
# key_name_date             2000-05-01_Apga      2000-05-02_Apga  \
# cg_name                             Apgar                Apgar
# date                  2000-05-01 00:00:00  2000-05-02 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             Apga                 Apga
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           122                  123
# day_of_month                            1                    2
# weekday                               Mon                  Tue
# key_year_month                   2000_May             2000_May
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
#
# key_name_date             2000-05-03_Apga      2000-05-04_Apga  \
# cg_name                             Apgar                Apgar
# date                  2000-05-03 00:00:00  2000-05-04 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             Apga                 Apga
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           124                  125
# day_of_month                            3                    4
# weekday                               Wed                  Thu
# key_year_month                   2000_May             2000_May
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
#
# key_name_date             2000-05-05_Apga      2000-05-06_Apga  \
# cg_name                             Apgar                Apgar
# date                  2000-05-05 00:00:00  2000-05-06 00:00:00
# did_fill                                1                    0
# fill_time                          9:25am                  NaN
# available                               1                    1
# nickname                             Apga                 Apga
# time_24                             09:25                    0
# hours_after_midnight                 9.42                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           126                  127
# day_of_month                            5                    6
# weekday                               Fri                  Sat
# key_year_month                   2000_May             2000_May
# high_season                             0                    0
# weekend                                 1                    1
# holiday                                 0                    0
# logan_pass                              0                    0
#
# key_name_date             2000-05-07_Apga      2000-05-08_Apga  \
# cg_name                             Apgar                Apgar
# date                  2000-05-07 00:00:00  2000-05-08 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             Apga                 Apga
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           128                  129
# day_of_month                            7                    8
# weekday                               Sun                  Mon
# key_year_month                   2000_May             2000_May
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
#
# key_name_date             2000-05-09_Apga      2000-05-10_Apga  ...  \
# cg_name                             Apgar                Apgar  ...
# date                  2000-05-09 00:00:00  2000-05-10 00:00:00  ...
# did_fill                                0                    0  ...
# fill_time                             NaN                  NaN  ...
# available                               1                    1  ...
# nickname                             Apga                 Apga  ...
# time_24                                 0                    0  ...
# hours_after_midnight                    0                    0  ...
# year                                 2000                 2000  ...
# month_num                               5                    5  ...
# month_text                            May                  May  ...
# day_of_year                           130                  131  ...
# day_of_month                            9                   10  ...
# weekday                               Tue                  Wed  ...
# key_year_month                   2000_May             2000_May  ...
# high_season                             0                    0  ...
# weekend                                 0                    0  ...
# holiday                                 0                    0  ...
# logan_pass                              0                    0  ...
#
# key_name_date             2019-09-21_TwoM      2019-09-22_TwoM  \
# cg_name                      Two Medicine         Two Medicine
# date                  2019-09-21 00:00:00  2019-09-22 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             TwoM                 TwoM
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           264                  265
# day_of_month                           21                   22
# weekday                               Sat                  Sun
# key_year_month                   2019_Sep             2019_Sep
# high_season                             0                    0
# weekend                                 1                    0
# holiday                                 0                    0
# logan_pass                              1                    1
#
# key_name_date             2019-09-23_TwoM      2019-09-24_TwoM  \
# cg_name                      Two Medicine         Two Medicine
# date                  2019-09-23 00:00:00  2019-09-24 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             TwoM                 TwoM
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           266                  267
# day_of_month                           23                   24
# weekday                               Mon                  Tue
# key_year_month                   2019_Sep             2019_Sep
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
#
# key_name_date             2019-09-25_TwoM      2019-09-26_TwoM  \
# cg_name                      Two Medicine         Two Medicine
# date                  2019-09-25 00:00:00  2019-09-26 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               1                    1
# nickname                             TwoM                 TwoM
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           268                  269
# day_of_month                           25                   26
# weekday                               Wed                  Thu
# key_year_month                   2019_Sep             2019_Sep
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
#
# key_name_date             2019-09-27_TwoM      2019-09-28_TwoM  \
# cg_name                      Two Medicine         Two Medicine
# date                  2019-09-27 00:00:00  2019-09-28 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               0                    0
# nickname                             TwoM                 TwoM
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           270                  271
# day_of_month                           27                   28
# weekday                               Fri                  Sat
# key_year_month                   2019_Sep             2019_Sep
# high_season                             0                    0
# weekend                                 1                    1
# holiday                                 0                    0
# logan_pass                              1                    1
#
# key_name_date             2019-09-29_TwoM      2019-09-30_TwoM
# cg_name                      Two Medicine         Two Medicine
# date                  2019-09-29 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# fill_time                             NaN                  NaN
# available                               0                    0
# nickname                             TwoM                 TwoM
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           272                  273
# day_of_month                           29                   30
# weekday                               Sun                  Mon
# key_year_month                   2019_Sep             2019_Sep
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
#
# [19 rows x 39780 columns]

# %% [markdown]
# -------------
#
# ## Read in Weather Data

# %%
df_weather = pd.read_csv('../data/03a_weather_clean.csv')
df_weather.drop(columns=["Unnamed: 0"],inplace=True)

df_weather = df_weather.set_index('date_wxstation');

# %% [markdown]
# #### Drop Irrelevant Columns

# %%
df_weather.drop(columns = [
    'LATITUDE',
    'LONGITUDE',
    'wx_station'
],inplace=True)

# %% [markdown]
# #### View Dataframe

# %%
df_weather.T
# Out:
# date_wxstation 2000-05-01_east_glac 2000-05-01_many_glac 2000-05-01_st_mary  \
# date                     2000-05-01           2000-05-01         2000-05-01
# PRCP                              0                    0                  0
# SNOW                              0                    0                  0
# TMAX                             70                   63                 70
# TMIN                             39                   37                 39
# did_PRCP                          0                    0                  0
# did_SNOW                          0                    0                  0
#
# date_wxstation 2000-05-01_west_glac 2000-05-02_east_glac 2000-05-02_many_glac  \
# date                     2000-05-01           2000-05-02           2000-05-02
# PRCP                              0                    0                    0
# SNOW                              0                    0                    0
# TMAX                             72                   53                   49
# TMIN                             31                   39                   37
# did_PRCP                          0                    0                    0
# did_SNOW                          0                    0                    0
#
# date_wxstation 2000-05-02_st_mary 2000-05-02_west_glac 2000-05-03_east_glac  \
# date                   2000-05-02           2000-05-02           2000-05-03
# PRCP                            0                 0.06                    0
# SNOW                            0                    0                    0
# TMAX                           53                   71                   58
# TMIN                           39                   40                   41
# did_PRCP                        0                    1                    0
# did_SNOW                        0                    0                    0
#
# date_wxstation 2000-05-03_many_glac  ... 2019-09-28_st_mary  \
# date                     2000-05-03  ...         2019-09-28
# PRCP                            0.7  ...                0.8
# SNOW                              0  ...                 15
# TMAX                             54  ...                 27
# TMIN                             40  ...                 22
# did_PRCP                          1  ...                  1
# did_SNOW                          0  ...                  1
#
# date_wxstation 2019-09-28_west_glac 2019-09-29_east_glac 2019-09-29_many_glac  \
# date                     2019-09-28           2019-09-29           2019-09-29
# PRCP                           0.12                 0.95                  0.4
# SNOW                              0                   19                   19
# TMAX                             51                   23                   29
# TMIN                             33                   21                   26
# did_PRCP                          1                    1                    1
# did_SNOW                          0                    1                    1
#
# date_wxstation 2019-09-29_st_mary 2019-09-29_west_glac 2019-09-30_east_glac  \
# date                   2019-09-29           2019-09-29           2019-09-30
# PRCP                          0.4                 0.02                 0.94
# SNOW                           19                    0                    7
# TMAX                           26                   41                   24
# TMIN                           23                   32                   20
# did_PRCP                        1                    1                    1
# did_SNOW                        1                    0                    1
#
# date_wxstation 2019-09-30_many_glac 2019-09-30_st_mary 2019-09-30_west_glac
# date                     2019-09-30         2019-09-30           2019-09-30
# PRCP                            0.1                0.1                 0.08
# SNOW                              7                  7                    0
# TMAX                             40                 33                   40
# TMIN                             18                 12                   30
# did_PRCP                          1                  1                    1
# did_SNOW                          1                  1                    0
#
# [7 rows x 12240 columns]

# %% [markdown]
# -------------
#
# ## Read in Visits Data

# %%
df_visits = pd.read_csv('../data/03b_monthly_visits_clean.csv')
df_visits.set_index('key_year_month',inplace=True)
df_visits = pd.DataFrame(df_visits['visits'].astype(int))

# %% [markdown]
# #### View Dataframe

# %%
df_visits
# Out:
#                 visits
# key_year_month
# 2019_Jan         13581
# 2018_Jan         12222
# 2017_Jan         14690
# 2016_Jan         15674
# 2015_Jan         12087
# ...                ...
# 2004_Dec         10174
# 2003_Dec         10073
# 2002_Dec          8334
# 2001_Dec          3387
# 2000_Dec          7522
#
# [240 rows x 1 columns]

# %% [markdown]
# ----------
#
# ## Read in Air Quality Data

# %%
df_aqi = pd.read_csv('../data/03c_air_quality_clean.csv')

# %% [markdown]
# #### Convert date to datetime and set date as index

# %%
df_aqi['date'] = pd.to_datetime(df_aqi['date'])
df_aqi.set_index('date',inplace=True)
df_aqi.sort_index(inplace=True)

# %% [markdown]
# #### Drop Irrelevant Columns

# %%
df_aqi.drop(columns=['Main Pollutant','date_aqi'],inplace=True)

# %% [markdown]
# #### View Dataframe

# %%
df_aqi
# Out:
#             aqi  ozone  PM10  PM25
# date
# 2000-01-01   60     28    16    60
# 2000-01-02   29     29    12    53
# 2000-01-03   40     28     9    46
# 2000-01-04   40     30     8    40
# 2000-01-05   33     33     7     7
# ...         ...    ...   ...   ...
# 2019-12-27   29     25    20    29
# 2019-12-28   37     20    17    37
# 2019-12-29   43     23    13    43
# 2019-12-30   38     19    17    38
# 2019-12-31   19     19    10    17
#
# [7305 rows x 4 columns]

# %% [markdown]
# ## Read in Campground Attributes

# %%
df_cg_attributes = pd.read_csv('../data/03d_campground_attributes_clean.csv',
                              index_col = 'cg_name')

# %% [markdown]
# #### View Dataframe

# %%
df_cg_attributes
# Out:
#                fee  sites  flush_toilets  showers  disposal_station  \
# cg_name
# Apgar           20    194              1        0                 1
# Avalanche       20     87              1        0                 0
# Bowman Lake     15     46              0        0                 0
# Cut Bank        10     14              0        0                 0
# Fish Creek      23    178              1        1                 1
# Kintla Lake     15     13              0        0                 0
# Logging Creek   10      7              0        0                 0
# Many Glacier    23    109              1        0                 1
# Quartz Creek    10      7              0        0                 0
# Rising Sun      20     84              1        1                 1
# Sprague Creek   20     25              1        0                 0
# St. Mary        23    148              1        1                 1
# Two Medicine    20    100              1        0                 1
#
#                reservations  rv  primitive  isolated nearest_wx_station
# cg_name
# Apgar                     0   1          0         0          west_glac
# Avalanche                 0   1          0         0          west_glac
# Bowman Lake               0   0          0         1          west_glac
# Cut Bank                  0   1          1         1          east_glac
# Fish Creek                1   1          0         0          west_glac
# Kintla Lake               0   0          0         1          west_glac
# Logging Creek             0   0          1         0          west_glac
# Many Glacier              0   1          0         1          many_glac
# Quartz Creek              0   0          1         0          west_glac
# Rising Sun                0   1          0         0            st_mary
# Sprague Creek             0   1          0         0          west_glac
# St. Mary                  1   1          0         0            st_mary
# Two Medicine              0   1          0         1          east_glac

# %% [markdown]
# --------
#
#
# # Integrate Dataframes
# [Back-to-top](#Back-to-Top)

# %% [markdown]
# #### Instantiate final df as df_fill

# %%
df = df_fill.copy()

df = df.sort_values(['date',
                     'cg_name'])

# %% [markdown]
# #### Join with AQI on 'date'

# %%
df = pd.merge(df,
              df_aqi,
              left_on = 'date',
              right_index = True,
              how = 'left')

# %% [markdown]
# #### Join with Monthly Visits on 'key_year_month'

# %%
df = pd.merge(df,
              df_visits,
              left_on = 'key_year_month',
              right_index = True,
              how = 'left')

# %% [markdown]
# #### Join with Campground Attributes at 'cg_name'

# %%
df = pd.merge(df,
              df_cg_attributes,
              left_on = 'cg_name',
              right_index = True,
              how = 'left')

# %% [markdown]
# #### Create 'Supply' Variable and Integrate

# %%
df['cg_supply'] = df['sites'] * df['available']
df_supply = pd.DataFrame(df.groupby('date')['cg_supply'].sum())

df = pd.merge(df,
             df_supply,
             left_on = 'date',
             right_index = True,
             how = 'left')

# %%
# I don't get how this works but it does?
df['cg_supply_y'] = df['cg_supply_y'] - df['sites'] * df['available']

# %% [markdown]
# #### Create 'date_wxstation' column to enable integration with weather dataframe

# %%
df['date_wxstation'] = df['date'].astype(str) + '_' + df['nearest_wx_station']

# %% [markdown]
# #### Join with Weather on 'date_wxstation'

# %%
df = pd.merge(df,
             df_weather,
             left_on = 'date_wxstation',
             right_index = True,
             how = 'left')

# %% [markdown]
# #### Drop Columns not of Interest

# %%
df = df.drop(columns = [
    
    # Fill Dates
    'fill_time',
    'nickname',
    'key_year_month',
    
    
    # Campground Attributes
    'nearest_wx_station',
    'cg_supply_x',
    
    # From Weather Data
    'date_wxstation',
    'date_y',
    
])

# %% [markdown]
# #### Examine Dataframe

# %%
df.T
# Out:
# key_name_date             2000-05-01_Apga      2000-05-01_Aval  \
# cg_name                             Apgar            Avalanche
# date_x                2000-05-01 00:00:00  2000-05-01 00:00:00
# did_fill                                0                    0
# available                               1                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           122                  122
# day_of_month                            1                    1
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
# aqi                                    38                   38
# ozone                                  34                   34
# PM10                                   38                   38
# PM25                                   32                   32
# visits                              86594                86594
# fee                                    20                   20
# sites                                 194                   87
# flush_toilets                           1                    1
# showers                                 0                    0
# disposal_station                        1                    0
# reservations                            0                    0
# rv                                      1                    1
# primitive                               0                    0
# isolated                                0                    0
# cg_supply_y                           148                  342
# PRCP                                    0                    0
# SNOW                                    0                    0
# TMAX                                   72                   72
# TMIN                                   31                   31
# did_PRCP                                0                    0
# did_SNOW                                0                    0
#
# key_name_date             2000-05-01_BoLa      2000-05-01_CuBa  \
# cg_name                       Bowman Lake             Cut Bank
# date_x                2000-05-01 00:00:00  2000-05-01 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           122                  122
# day_of_month                            1                    1
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
# aqi                                    38                   38
# ozone                                  34                   34
# PM10                                   38                   38
# PM25                                   32                   32
# visits                              86594                86594
# fee                                    15                   10
# sites                                  46                   14
# flush_toilets                           0                    0
# showers                                 0                    0
# disposal_station                        0                    0
# reservations                            0                    0
# rv                                      0                    1
# primitive                               0                    1
# isolated                                1                    1
# cg_supply_y                           342                  342
# PRCP                                    0                    0
# SNOW                                    0                    0
# TMAX                                   72                   70
# TMIN                                   31                   39
# did_PRCP                                0                    0
# did_SNOW                                0                    0
#
# key_name_date             2000-05-01_FiCr      2000-05-01_KiLa  \
# cg_name                        Fish Creek          Kintla Lake
# date_x                2000-05-01 00:00:00  2000-05-01 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           122                  122
# day_of_month                            1                    1
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
# aqi                                    38                   38
# ozone                                  34                   34
# PM10                                   38                   38
# PM25                                   32                   32
# visits                              86594                86594
# fee                                    23                   15
# sites                                 178                   13
# flush_toilets                           1                    0
# showers                                 1                    0
# disposal_station                        1                    0
# reservations                            1                    0
# rv                                      1                    0
# primitive                               0                    0
# isolated                                0                    1
# cg_supply_y                           342                  342
# PRCP                                    0                    0
# SNOW                                    0                    0
# TMAX                                   72                   72
# TMIN                                   31                   31
# did_PRCP                                0                    0
# did_SNOW                                0                    0
#
# key_name_date             2000-05-01_LoCr      2000-05-01_MaGl  \
# cg_name                     Logging Creek         Many Glacier
# date_x                2000-05-01 00:00:00  2000-05-01 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2000                 2000
# month_num                               5                    5
# month_text                            May                  May
# day_of_year                           122                  122
# day_of_month                            1                    1
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              0                    0
# aqi                                    38                   38
# ozone                                  34                   34
# PM10                                   38                   38
# PM25                                   32                   32
# visits                              86594                86594
# fee                                    10                   23
# sites                                   7                  109
# flush_toilets                           0                    1
# showers                                 0                    0
# disposal_station                        0                    1
# reservations                            0                    0
# rv                                      0                    1
# primitive                               1                    0
# isolated                                0                    1
# cg_supply_y                           342                  342
# PRCP                                    0                    0
# SNOW                                    0                    0
# TMAX                                   72                   63
# TMIN                                   31                   37
# did_PRCP                                0                    0
# did_SNOW                                0                    0
#
# key_name_date             2000-05-01_QuCr      2000-05-01_RiSu  ...  \
# cg_name                      Quartz Creek           Rising Sun  ...
# date_x                2000-05-01 00:00:00  2000-05-01 00:00:00  ...
# did_fill                                0                    0  ...
# available                               0                    0  ...
# time_24                                 0                    0  ...
# hours_after_midnight                    0                    0  ...
# year                                 2000                 2000  ...
# month_num                               5                    5  ...
# month_text                            May                  May  ...
# day_of_year                           122                  122  ...
# day_of_month                            1                    1  ...
# weekday                               Mon                  Mon  ...
# high_season                             0                    0  ...
# weekend                                 0                    0  ...
# holiday                                 0                    0  ...
# logan_pass                              0                    0  ...
# aqi                                    38                   38  ...
# ozone                                  34                   34  ...
# PM10                                   38                   38  ...
# PM25                                   32                   32  ...
# visits                              86594                86594  ...
# fee                                    10                   20  ...
# sites                                   7                   84  ...
# flush_toilets                           0                    1  ...
# showers                                 0                    1  ...
# disposal_station                        0                    1  ...
# reservations                            0                    0  ...
# rv                                      0                    1  ...
# primitive                               1                    0  ...
# isolated                                0                    0  ...
# cg_supply_y                           342                  342  ...
# PRCP                                    0                    0  ...
# SNOW                                    0                    0  ...
# TMAX                                   72                   70  ...
# TMIN                                   31                   39  ...
# did_PRCP                                0                    0  ...
# did_SNOW                                0                    0  ...
#
# key_name_date             2019-09-30_CuBa      2019-09-30_FiCr  \
# cg_name                          Cut Bank           Fish Creek
# date_x                2019-09-30 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           273                  273
# day_of_month                           30                   30
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
# aqi                                    25                   25
# ozone                                  25                   25
# PM10                                   10                   10
# PM25                                   11                   11
# visits                             488909               488909
# fee                                    10                   23
# sites                                  14                  178
# flush_toilets                           0                    1
# showers                                 0                    1
# disposal_station                        0                    1
# reservations                            0                    1
# rv                                      1                    1
# primitive                               1                    0
# isolated                                1                    0
# cg_supply_y                           349                  349
# PRCP                                 0.94                 0.08
# SNOW                                    7                    0
# TMAX                                   24                   40
# TMIN                                   20                   30
# did_PRCP                                1                    1
# did_SNOW                                1                    0
#
# key_name_date             2019-09-30_KiLa      2019-09-30_LoCr  \
# cg_name                       Kintla Lake        Logging Creek
# date_x                2019-09-30 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           273                  273
# day_of_month                           30                   30
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
# aqi                                    25                   25
# ozone                                  25                   25
# PM10                                   10                   10
# PM25                                   11                   11
# visits                             488909               488909
# fee                                    15                   10
# sites                                  13                    7
# flush_toilets                           0                    0
# showers                                 0                    0
# disposal_station                        0                    0
# reservations                            0                    0
# rv                                      0                    0
# primitive                               0                    1
# isolated                                1                    0
# cg_supply_y                           349                  349
# PRCP                                 0.08                 0.08
# SNOW                                    0                    0
# TMAX                                   40                   40
# TMIN                                   30                   30
# did_PRCP                                1                    1
# did_SNOW                                0                    0
#
# key_name_date             2019-09-30_MaGl      2019-09-30_QuCr  \
# cg_name                      Many Glacier         Quartz Creek
# date_x                2019-09-30 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# available                               0                    1
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           273                  273
# day_of_month                           30                   30
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
# aqi                                    25                   25
# ozone                                  25                   25
# PM10                                   10                   10
# PM25                                   11                   11
# visits                             488909               488909
# fee                                    23                   10
# sites                                 109                    7
# flush_toilets                           1                    0
# showers                                 0                    0
# disposal_station                        1                    0
# reservations                            0                    0
# rv                                      1                    0
# primitive                               0                    1
# isolated                                1                    0
# cg_supply_y                           349                  342
# PRCP                                  0.1                 0.08
# SNOW                                    7                    0
# TMAX                                   40                   40
# TMIN                                   18                   30
# did_PRCP                                1                    1
# did_SNOW                                1                    0
#
# key_name_date             2019-09-30_RiSu      2019-09-30_SpCr  \
# cg_name                        Rising Sun        Sprague Creek
# date_x                2019-09-30 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# available                               0                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           273                  273
# day_of_month                           30                   30
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
# aqi                                    25                   25
# ozone                                  25                   25
# PM10                                   10                   10
# PM25                                   11                   11
# visits                             488909               488909
# fee                                    20                   20
# sites                                  84                   25
# flush_toilets                           1                    1
# showers                                 1                    0
# disposal_station                        1                    0
# reservations                            0                    0
# rv                                      1                    1
# primitive                               0                    0
# isolated                                0                    0
# cg_supply_y                           349                  349
# PRCP                                  0.1                 0.08
# SNOW                                    7                    0
# TMAX                                   33                   40
# TMIN                                   12                   30
# did_PRCP                                1                    1
# did_SNOW                                1                    0
#
# key_name_date             2019-09-30_StMa      2019-09-30_TwoM
# cg_name                          St. Mary         Two Medicine
# date_x                2019-09-30 00:00:00  2019-09-30 00:00:00
# did_fill                                0                    0
# available                               1                    0
# time_24                                 0                    0
# hours_after_midnight                    0                    0
# year                                 2019                 2019
# month_num                               9                    9
# month_text                            Sep                  Sep
# day_of_year                           273                  273
# day_of_month                           30                   30
# weekday                               Mon                  Mon
# high_season                             0                    0
# weekend                                 0                    0
# holiday                                 0                    0
# logan_pass                              1                    1
# aqi                                    25                   25
# ozone                                  25                   25
# PM10                                   10                   10
# PM25                                   11                   11
# visits                             488909               488909
# fee                                    23                   20
# sites                                 148                  100
# flush_toilets                           1                    1
# showers                                 1                    0
# disposal_station                        1                    1
# reservations                            1                    0
# rv                                      1                    1
# primitive                               0                    0
# isolated                                0                    1
# cg_supply_y                           201                  349
# PRCP                                  0.1                 0.94
# SNOW                                    7                    7
# TMAX                                   33                   24
# TMIN                                   12                   20
# did_PRCP                                1                    1
# did_SNOW                                1                    1
#
# [37 rows x 39780 columns]

# %% [markdown]
# # Export Dataframe
#
# [Back-to-top](#Back-to-Top)

# %%
df.to_csv('../data/04_Full_DataFrame.csv')
